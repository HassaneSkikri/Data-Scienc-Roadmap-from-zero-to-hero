# %% [markdown]
# ### Mongodb Aggregate And Group
# 1. avg
# 2. sum
# 3. project

# %%
from pymongo import MongoClient  
    
# creation of object MongoClient  
client=MongoClient()  
    
# Connect with the portnumber and host  
client = MongoClient("mongodb://localhost:27017/")  
    
# Access database  
mydatabase = client['Students']  
    
# Access collection of the database  
collection=mydatabase['studentscores']  
data = [ 
    {"user":"skikri", "subject":"Database", "score":80}, 
    {"user":"anas",  "subject":"JavaScript", "score":90}, 
    {"user":"anas",  "title":"Database", "score":85}, 
    {"user":"skikri",  "title":"JavaScript", "score":75}, 
    {"user":"anas",  "title":"Data Science", "score":60},
    {"user":"skikri",  "title":"Data Science", "score":95}] 
  
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('663a0b7e7a220d0170cf31c1'), ObjectId('663a0b7e7a220d0170cf31c2'), ObjectId('663a0b7e7a220d0170cf31c3'), ObjectId('663a0b7e7a220d0170cf31c4'), ObjectId('663a0b7e7a220d0170cf31c5'), ObjectId('663a0b7e7a220d0170cf31c6')], acknowledged=True)

# %%
### Find anas And skikri Total Subjects
agg_result= collection.aggregate( 
    [{ 
    "$group" :  
        {"_id" : "$user",  
         "Total Subject" : {"$sum" : 1} 
         }} 
    ])

# %%
for i in agg_result: 
    print(i)
# Out:
# {'_id': 'anas', 'Total Subject': 3}
# {'_id': 'skikri', 'Total Subject': 3}

# %%
### Calculating the total score based on user
agg_result= collection.aggregate( 
    [{ 
    "$group" :  
        {"_id" : "$user",  
         "Total Marks" : {"$sum" :"$score"} 
         }} 
    ]) 
for i in agg_result: 
    print(i)
# Out:
# {'_id': 'anas', 'Total Marks': 235}
# {'_id': 'skikri', 'Total Marks': 250}

# %%
### Calculating the average score based on user
agg_result=collection.aggregate([
   {
      "$group": {
         "_id": '$user',
         "StudentScoreAverage": {
            "$avg": "$score"
         }
      }
   }
])
for i in agg_result: 
    print(i)
# Out:
# {'_id': 'anas', 'StudentScoreAverage': 78.33333333333333}
# {'_id': 'skikri', 'StudentScoreAverage': 83.33333333333333}

# %%
import datetime as datetime

# %%
### Create a new collection
data=[{ "_id" : 1, "item" : "abc", "price" : 10, "quantity" : 2, "date" : datetime.datetime.utcnow()},
{ "_id" : 2, "item" : "jkl", "price" : 20, "quantity" : 1, "date" : datetime.datetime.utcnow() },
{ "_id" : 3, "item" : "xyz", "price" : 5, "quantity" : 5, "date" : datetime.datetime.utcnow() },
{ "_id" : 4, "item" : "abc", "price" : 10, "quantity" : 10, "date" : datetime.datetime.utcnow() },
{ "_id" : 5, "item" : "xyz", "price" : 5, "quantity" : 10, "date" :datetime.datetime.utcnow() }]
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_17756\1712232565.py:2: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   data=[{ "_id" : 1, "item" : "abc", "price" : 10, "quantity" : 2, "date" : datetime.datetime.utcnow()},
# C:\Users\hassa\AppData\Local\Temp\ipykernel_17756\1712232565.py:3: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   { "_id" : 2, "item" : "jkl", "price" : 20, "quantity" : 1, "date" : datetime.datetime.utcnow() },
# ...

# %%
data
# Out:
# [{'_id': 1,
#   'item': 'abc',
#   'price': 10,
#   'quantity': 2,
#   'date': datetime.datetime(2024, 5, 7, 11, 9, 25, 648576)},
#  {'_id': 2,
#   'item': 'jkl',
#   'price': 20,
#   'quantity': 1,
#   'date': datetime.datetime(2024, 5, 7, 11, 9, 25, 648576)},
#  {'_id': 3,
#   'item': 'xyz',
#   'price': 5,
#   'quantity': 5,
#   'date': datetime.datetime(2024, 5, 7, 11, 9, 25, 648576)},
#  {'_id': 4,
#   'item': 'abc',
#   'price': 10,
#   'quantity': 10,
#   'date': datetime.datetime(2024, 5, 7, 11, 9, 25, 648576)},
#  {'_id': 5,
#   'item': 'xyz',
#   'price': 5,
#   'quantity': 10,
#   'date': datetime.datetime(2024, 5, 7, 11, 9, 25, 648576)}]

# %%
mycollection=mydatabase['stores']  
mycollection.insert_many(data)
# Out:
# InsertManyResult([1, 2, 3, 4, 5], acknowledged=True)

# %%
### Calculating the average quantity And Average Price
agg_result=mycollection.aggregate([
   {
      "$group": {
         "_id": '$item',
         "avgAmount": {"$avg": {"$multiply": [ "$price", "$quantity" ]}},
          "avgQuantity": { "$avg": "$quantity" }
      }
   }
])
for i in agg_result: 
    print(i)
# Out:
# {'_id': 'jkl', 'avgAmount': 20.0, 'avgQuantity': 1.0}
# {'_id': 'xyz', 'avgAmount': 37.5, 'avgQuantity': 7.5}
# {'_id': 'abc', 'avgAmount': 60.0, 'avgQuantity': 6.0}

# %%
#### $Project

data=[{
  "_id" : 1,
  "title": "abc123",
  "isbn": "0001122223334",
  "author": { "last": "zzz", "first": "aaa" },
  "copies": 5
},
{
  "_id" : 2,
  "title": "Baked Goods",
  "isbn": "9999999999999",
  "author": { "last": "xyz", "first": "abc", "middle": "" },
  "copies": 2
}
]

# %%
# Access collection of the database  
collection=mydatabase['Books']

# %%
collection.insert_many(data)
# Out:
# InsertManyResult([1, 2], acknowledged=True)

# %%
for row in collection.aggregate( [ { "$project": { "title": 1,"isbn":1 } } ] ):
    print(row)
# Out:
# {'_id': 1, 'title': 'abc123', 'isbn': '0001122223334'}
# {'_id': 2, 'title': 'Baked Goods', 'isbn': '9999999999999'}
